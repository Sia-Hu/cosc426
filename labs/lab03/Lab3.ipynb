# %% [markdown]
# # Lab 3: Grammar writing
# ### COSC 426: Fall 2025, Colgate University
#
# Use this notebook to answer the questions in `Lab3.md`. Make sure to include in this notebook all the tests you run to ensure that at each stage your grammar is correct.

# %% [markdown]
# ## Part 0
#
# Run the following code chunks, and make sure you understand what these code chunks are doing, and the format of the output they generate.

# %%
import Lab3
import nltk
import math

# %%
grammar = Lab3.create_pcfg('starter_grammar.txt')
sents = Lab3.generate_sentences(grammar, 5)

for sent in sents:
    print(f"prob:{sent[1]} \t sent: {sent[0]} \n")
# Out:
# prob:-17.017650706821687 	 sent: the pajamas in my pajamas ate my sandwich
#
# prob:-10.766111939825723 	 sent: a pajamas saw my panda
#
# prob:-34.9421920092519 	 sent: her friend ate the sandwich in the friend in a panda in a pajamas in the panda
#
# prob:-23.269189473817654 	 sent: a panda in her friend ate her pajamas in my sandwich
#
# prob:-41.19373077624786 	 sent: my pajamas in the friend in my pajamas in my panda ate her pajamas in my friend in my friend

# %%
sentence = 'a panda in a friend in a sandwich ate my pajamas'
parses = list(Lab3.parse_sentence("starter_grammar.txt", sentence))

for tree in parses:
    tree.pretty_print()
    print(math.log2(tree.prob()), '\n')
# Out:
#                                  ROOT
#                                   |
#                                   S
#                     ______________|_________________________
#                    NP                                       |
#       _____________|________                                |
#      |                      PP                              |
#      |          ____________|_____                          |
#      |         |                  NP                        |
#      |         |        __________|____                     |
#      |         |       |               PP                   VP
#      |         |       |           ____|___              ___|___
#      NP        |       NP         |        NP           |       NP
#   ___|____     |    ___|____      |     ___|_____       |    ___|_____
# Det       N    P  Det       N     P   Det        N      V  Det        N
#  |        |    |   |        |     |    |         |      |   |         |
#  a      panda  in  a      friend  in   a      sandwich ate  my     pajamas
#
# -23.26918947381765
#
#                                  ROOT
#                                   |
#                                   S
#                     ______________|_________________________
#                    NP                                       |
#                 ___|___________________                     |
#                NP                      |                    |
#       _________|___                    |                    |
#      |             PP                  PP                   VP
#      |          ___|___            ____|___              ___|___
#      NP        |       NP         |        NP           |       NP
#   ___|____     |    ___|____      |     ___|_____       |    ___|_____
# Det       N    P  Det       N     P   Det        N      V  Det        N
#  |        |    |   |        |     |    |         |      |   |         |
#  a      panda  in  a      friend  in   a      sandwich ate  my     pajamas
#
# -23.26918947381765

# %% [markdown]
# ## Part 1
#
# Answer the questions in Part 1. Feel free to add as many markdown or code chunks as you need.

# %%
sentence = 'a panda in a friend ate my pajamas in a sandwich'
parses = list(Lab3.parse_sentence("starter_grammar.txt", sentence))

for tree in parses:
    tree.pretty_print()
    print(math.log2(tree.prob()), '\n')
# Out:
#                                  ROOT
#                                   |
#                                   S
#                 __________________|______________
#                NP                                VP
#       _________|___                     _________|_________
#      |             PP                  VP                  PP
#      |          ___|___            ____|___             ___|___
#      NP        |       NP         |        NP          |       NP
#   ___|____     |    ___|____      |     ___|_____      |    ___|_____
# Det       N    P  Det       N     V   Det        N     P  Det        N
#  |        |    |   |        |     |    |         |     |   |         |
#  a      panda  in  a      friend ate   my     pajamas  in  a      sandwich
#
# -22.85415197453881
#
#                                  ROOT
#                                   |
#                                   S
#                 __________________|______________
#                |                                 VP
#                |                   ______________|_____
#                NP                 |                    NP
#       _________|___               |         ___________|___
#      |             PP             |        |               PP
#      |          ___|___           |        |            ___|___
#      NP        |       NP         |        NP          |       NP
#   ___|____     |    ___|____      |     ___|_____      |    ___|_____
# Det       N    P  Det       N     V   Det        N     P  Det        N
#  |        |    |   |        |     |    |         |     |   |         |
#  a      panda  in  a      friend ate   my     pajamas  in  a      sandwich
#
# -23.26918947381765

# %% [markdown]
# #### 1
# First interpretation: The verb phrase is "ate my pajamas", and the entire action is modified by "in a sandwich". In other words, the panda (that is inside a friend) ate my pajamas, and this act of eating happened in a sandwich.
#
# Second interpretation: The phrase "in a sandwich" modifies only "my pajamas", meaning the panda (in a friend) ate my pajamas, which themselves were inside a sandwich.

# %% [markdown]
# #### 2
# Some factors that influence the probability are:
#
# Sentence length: Longer sentences generally have lower probability because each additional word multiplies the probability by a smaller factor.
#
# Rule choice in the grammar: Even for sentences of the same length, different parse trees can have different probabilities depending on which production rules were applied.

# %% [markdown]
# #### 3

# %%
sentence = 'a panda in a friend ate my pajamas in a sandwich'
parses = list(Lab3.parse_sentence("grammar1.txt", sentence))

for tree in parses:
    tree.pretty_print()
    print(math.log2(tree.prob()), '\n')
# Out:
#                                  ROOT
#                                   |
#                                   S
#                 __________________|______________
#                NP                                VP
#       _________|___                     _________|_________
#      |             PP                  VP                  PP
#      |          ___|___            ____|___             ___|___
#      NP        |       NP         |        NP          |       NP
#   ___|____     |    ___|____      |     ___|_____      |    ___|_____
# Det       N    P  Det       N     V   Det        N     P  Det        N
#  |        |    |   |        |     |    |         |     |   |         |
#  a      panda  in  a      friend ate   my     pajamas  in  a      sandwich
#
# -23.253496664211536
#
#                                  ROOT
#                                   |
#                                   S
#                 __________________|______________
#                |                                 VP
#                |                   ______________|_____
#                NP                 |                    NP
#       _________|___               |         ___________|___
#      |             PP             |        |               PP
#      |          ___|___           |        |            ___|___
#      NP        |       NP         |        NP          |       NP
#   ___|____     |    ___|____      |     ___|_____      |    ___|_____
# Det       N    P  Det       N     V   Det        N     P  Det        N
#  |        |    |   |        |     |    |         |     |   |         |
#  a      panda  in  a      friend ate   my     pajamas  in  a      sandwich
#
# -23.253496664211536

# %% [markdown]
# #### 4

# %%
grammar = Lab3.create_pcfg('grammar1.txt')
sents = Lab3.generate_sentences(grammar, 25)

for sent in sents:
    print(f"prob:{sent[1]} \t sent: {sent[0]} \n")
# Out:
# prob:-23.253496664211532 	 sent: my panda saw my friend in the panda in my friend
#
# prob:-16.60964047443681 	 sent: my sandwich ate a pajamas in the pajamas
#
# prob:-9.965784284662087 	 sent: the panda ate a panda
#
# prob:-9.965784284662087 	 sent: her friend saw the panda
#
# prob:-16.60964047443681 	 sent: my friend saw a friend in a sandwich
#
# prob:-16.60964047443681 	 sent: my sandwich saw her pajamas in the pajamas
#
# prob:-9.965784284662087 	 sent: the panda saw a pajamas
#
# prob:-23.253496664211532 	 sent: a pajamas ate her panda in my pajamas in her panda
#
# prob:-9.965784284662087 	 sent: my panda saw a friend
#
# prob:-9.965784284662087 	 sent: a friend saw the pajamas
#
# prob:-16.60964047443681 	 sent: a pajamas ate my friend in a pajamas
#
# prob:-23.253496664211532 	 sent: my friend in the panda in her friend saw her sandwich
#
# prob:-9.965784284662087 	 sent: her sandwich ate my sandwich
#
# prob:-9.965784284662087 	 sent: the pajamas saw her pajamas
#
# prob:-9.965784284662087 	 sent: the sandwich saw her sandwich
#
# prob:-29.89735285398626 	 sent: my panda saw a panda in her pajamas in the sandwich in her pajamas
#
# prob:-9.965784284662087 	 sent: her pajamas saw a sandwich
#
# prob:-9.965784284662087 	 sent: her sandwich ate her sandwich
#
# prob:-16.60964047443681 	 sent: her sandwich saw the friend in her sandwich
#
# prob:-23.253496664211532 	 sent: her panda ate my friend in a friend in my panda
#
# prob:-9.965784284662087 	 sent: her friend saw the panda
#
# prob:-16.60964047443681 	 sent: a friend saw a panda in my pajamas
#
# prob:-16.60964047443681 	 sent: the sandwich in the panda ate the friend
#
# prob:-9.965784284662087 	 sent: the sandwich ate my pajamas
#
# prob:-16.60964047443681 	 sent: the pajamas ate the sandwich in the panda

# %% [markdown]
# #### 5

# %%
def is_grammatical(grammar_fname, sent):
    """
    Returns True if sentence is grammatical given grammar, False otherwise
    """
    parse = list(Lab3.parse_sentence(grammar_fname, sent))
    return len(parse) > 0

# %% [markdown]
# ## Part 2
#
# Answer the questions in Part 2. Feel free to add as many markdown or code chunks as you need.

# %%
sent = ['the panda existed',
'the panda ate',
'the panda ate the sandwich',
'the sandwich saw the panda in my friend',
'the sandwich in my friend died in the panda',
'my friend vanished in the sandwich',
'my friend saw the sandwich in the panda in my friend',

'the panda vanished my friend',
'the sandwich existed the panda',
'my friend in the sandwich died the panda',
'the panda died the sandwich in my friend']

for s in sent:
    print(is_grammatical('grammar2.txt', s), " : ", s)
# Out:
# True  :  the panda existed
# True  :  the panda ate
# True  :  the panda ate the sandwich
# True  :  the sandwich saw the panda in my friend
# True  :  the sandwich in my friend died in the panda
# True  :  my friend vanished in the sandwich
# True  :  my friend saw the sandwich in the panda in my friend
# False  :  the panda vanished my friend
# False  :  the sandwich existed the panda
# False  :  my friend in the sandwich died the panda
# False  :  the panda died the sandwich in my friend

# %% [markdown]
# There are certain verbs that just apply to a subject, and don't apply from a subject to another noun phrase. In our grammar, V2 contains verbs that are intransitive, meaning you can't apply them to an object after them.

# %% [markdown]
# ## Part 3
#
# Answer the questions in Part 3. Feel free to add as many markdown or code chunks as you need.

# %% [markdown]
# Arbetrary number of adjectives, very very very very strong.

# %%
sent = ['the ponderous panda existed',
'the excited excited ponderous panda ate the sandwich',
'the panda saw my very delicious delicious sandwich in my very very ponderous pajamas',
'the very very very excited panda died',
'the very excited very delicious sandwich vanished',
'the panda ponderous existed',
'the ponderous panda excited vanished',
'the panda in the ponderous very pajamas saw my friend']

for s in sent:
    print(is_grammatical('grammar3.txt', s), " : ", s)
# Out:
# True  :  the ponderous panda existed
# True  :  the excited excited ponderous panda ate the sandwich
# True  :  the panda saw my very delicious delicious sandwich in my very very ponderous pajamas
# True  :  the very very very excited panda died
# True  :  the very excited very delicious sandwich vanished
# False  :  the panda ponderous existed
# False  :  the ponderous panda excited vanished
# False  :  the panda in the ponderous very pajamas saw my friend

# %% [markdown]
# You are able to add any number of adjectives on the left of any noun to modify it. You are able to add any number of 'very' to the left of any adjective to modify it.

# %% [markdown]
# ## Part 4
#
# Answer the questions in Part 4. Feel free to add as many markdown or code chunks as you need.

# %%
sent = ['the panda vanished peacefully',
'the ponderous pajamas peacefully died',
'peacefully the ponderous pajamas died',
'the ponderous pajamas existed peacefully in my pajamas',
'the panda peacefully saw the ponderous friend in my pajamas',
'the panda saw the ponderous friend peacefully in my pajamas',
'the panda saw the ponderous friend in my pajamas peacefully',
'my very very ponderous friend existed very very very peacefully.',
'my friend ate the excited delicious sandwich peacefully joyfully in my pajamas',

'the panda joyfully vanished peacefully',
'my ponderous friend existed peacefully very very',
'my friend very saw the sandwich in the pajamas',
'my friend very saw peacefully the sandwich in the pajamas',
'the joyfully pajamas saw the sandwich in the pajamas']

for s in sent:
    # sentence level
    print(is_grammatical('grammar4_1.txt', s), " : ", s)
print()
for s in sent:
    # VP level
    print(is_grammatical('grammar4.txt', s), " : ", s)
# Out:
# True  :  the panda vanished peacefully
# True  :  the ponderous pajamas peacefully died
# True  :  peacefully the ponderous pajamas died
# True  :  the ponderous pajamas existed peacefully in my pajamas
# True  :  the panda peacefully saw the ponderous friend in my pajamas
# True  :  the panda saw the ponderous friend peacefully in my pajamas
# True  :  the panda saw the ponderous friend in my pajamas peacefully
# False  :  my very very ponderous friend existed very very very peacefully.
# False  :  my friend ate the excited delicious sandwich peacefully joyfully in my pajamas
# False  :  the panda joyfully vanished peacefully
# False  :  my ponderous friend existed peacefully very very
# False  :  my friend very saw the sandwich in the pajamas
# False  :  my friend very saw peacefully the sandwich in the pajamas
# False  :  the joyfully pajamas saw the sandwich in the pajamas
#
# True  :  the panda vanished peacefully
# True  :  the ponderous pajamas peacefully died
# False  :  peacefully the ponderous pajamas died
# True  :  the ponderous pajamas existed peacefully in my pajamas
# True  :  the panda peacefully saw the ponderous friend in my pajamas
# True  :  the panda saw the ponderous friend peacefully in my pajamas
# True  :  the panda saw the ponderous friend in my pajamas peacefully
# False  :  my very very ponderous friend existed very very very peacefully.
# True  :  my friend ate the excited delicious sandwich peacefully joyfully in my pajamas
# True  :  the panda joyfully vanished peacefully
# False  :  my ponderous friend existed peacefully very very
# False  :  my friend very saw the sandwich in the pajamas
# False  :  my friend very saw peacefully the sandwich in the pajamas
# False  :  the joyfully pajamas saw the sandwich in the pajamas

# %% [markdown]
# You're able to insert adverbs into a single position in the sentence to modify the verb. You're able to have multiple adverbs in the same place.

# %% [markdown]
# ## Part 5
#
# Answer the questions in Part 5. Feel free to add as many markdown or code chunks as you need.

# %%
sent = ['the panda that existed very peacefully vanished joyfully',
'my friend saw the panda that existed very peacefully',
'the panda that existed very joyfully died peacefully',
'the panda saw my friend that joyfully ate the sandwich in her pajamas',
'the panda saw my very excited friend in her pajamas that joyfully peacefully existed',

'the panda that existed my friend ate the sandwich',
'the sandwich saw that my friend existed',
'the panda that vanished peacefully in my friend',
'the panda existed very joyfully died peacefully']

for s in sent:
    print(is_grammatical('grammar5.txt', s), " : ", s)
# Out:
# True  :  the panda that existed very peacefully vanished joyfully
# True  :  my friend saw the panda that existed very peacefully
# True  :  the panda that existed very joyfully died peacefully
# True  :  the panda saw my friend that joyfully ate the sandwich in her pajamas
# True  :  the panda saw my very excited friend in her pajamas that joyfully peacefully existed
# False  :  the panda that existed my friend ate the sandwich
# False  :  the sandwich saw that my friend existed
# False  :  the panda that vanished peacefully in my friend
# False  :  the panda existed very joyfully died peacefully

# %% [markdown]
# Rrelative clauses beginning with "that" can modify noun phrases. The relative clause must be grammatically complete on its own and it appears immediately after the noun it modifies.

# %% [markdown]
# ## Part 6
#
# Answer the questions in Part 6. Feel free to add as many markdown or code chunks as you need.

# %%
sent = ['that my friend ate the excited delicious sandwich peacefully joyfully in my pajamas pleased the panda',
'that the excited panda vanished peacefully perplexed my friend',
'that my friend in the pajamas saw the very very very excited panda surprised the sandwich',
'that the panda that existed very peacefully vanished joyfully perplexed my friend',
'that the panda that existed very peacefully vanished joyfully perplexed my friend that ate the sandwich',

'that my friend pleased the panda ate the excited delicious sandwich',
'that the excited panda vanished peacefully perplexed',
'my friend in the pajamas saw the very very very excited panda surprised the sandwich',
'that the panda existed very peacefully vanished joyfully surprised my friend that']

for s in sent:
    print(is_grammatical('grammar6.txt', s), " : ", s)
# Out:
# True  :  that my friend ate the excited delicious sandwich peacefully joyfully in my pajamas pleased the panda
# True  :  that the excited panda vanished peacefully perplexed my friend
# True  :  that my friend in the pajamas saw the very very very excited panda surprised the sandwich
# True  :  that the panda that existed very peacefully vanished joyfully perplexed my friend
# True  :  that the panda that existed very peacefully vanished joyfully perplexed my friend that ate the sandwich
# False  :  that my friend pleased the panda ate the excited delicious sandwich
# False  :  that the excited panda vanished peacefully perplexed
# False  :  my friend in the pajamas saw the very very very excited panda surprised the sandwich
# False  :  that the panda existed very peacefully vanished joyfully surprised my friend that

# %% [markdown]
# Complete sentences can be moved to the beginning and introduced by "that" to serve as the subject of another sentence, where the main clause contains verbs (V3) that take sentential subjects. The fronted clause must be a complete grammatical sentence, and the main clause must have a verb that can take a sentential complement as its subject, followed by a direct object.
